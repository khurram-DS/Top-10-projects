# %% [markdown]
# # Table of Content

# %% [raw]
# 1.HR Analytics and Attrition Introduction.
#
# 2.Analyzing HR Attrition Dataset.
#
#         a.Problem Statement or How Attrition affecting companies.
#         b.Data Loading and Description
#         c.Summary Statistic
#         d.Exploratory Data Analysis
#            *All the parameter Analysis based on attrition.
#
# 3.Decompositing the column using PCA techniques.
#
# 4.Building model for prediction
#         a.Predicting,Evaluating,testing Attrition Rate in company using various classification models.
#         b.Used all the ensemble boosting techniques.
#         c.Plotted the best predicted result of model using distplot.
#
# 5.Conclusion

# %% [markdown]
# # HR ANALYTICS PROJECT

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# # What is HR ANALYTICS

# %% [markdown]
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# # Lets know about Attrition in Human Resource Company! so What is Attrition In HR

# %% [markdown]
# Attrition in human resources refers to the gradual loss of employees over time. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question we will write the code and try to understand the process step by step.

# %% [markdown]
# # Problem Statement or How Attrition affection Companies?

# %% [markdown]
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# Above what we discussed is all About HR ANALYTICS, ATTRITION IN HR , how its affecting
# companies, thats the verbal thing, why cant we just go and check the real thing with visulaization technique and, lets predict the model and go in depth and lets understand with real technique,
# for that we just need to load a data set and explore it with our Data Handling techniques.
# lets just load the IBM HR ANALYTICS data , following this link https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics

# %% [markdown]
# # Data loading and description

# %%
import pandas as pd
data=pd.read_csv('hr.csv')
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data.shape
# we can observe the shape above there is 1470 row, with 35 columns.
# Out:
# (1470, 35)

# %% [raw]
# observation:
# As we can observe and can see that for this dataset our aim is to predict the employee attrition, and check which columns is more contributing the most in attrition lets analyze it.

# %%
#lets check the null value in HR nalytics dataset.
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# Observation:
#     we can observe above there in no null value present above in the dataset.

# %%
#lets check the data information.
data.info()
# we can observe different data types of HR data set.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Summary Statistics

# %%
#lets check the discription of dataset
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# As we cant see all the column description lets describe using iloc
data.iloc[:,10:-10].describe()
# Out:
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    48.000000        2.000000     1.000000
# 50%                   3.000000    66.000000        3.000000     2.000000
# 75%                   4.000000    83.750000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count      1470.000000    1470.000000   1470.000000         1470.000000
# mean          2.728571    6502.931293  14313.103401            2.693197
# std           1.102846    4707.956783   7117.786044            2.498009
# ...

# %% [raw]
# observation:
#
#     1. we can observe description of HR analytics dataset above, we can observe the Age column minimum age
#        we can observe 36 and maximum we can observe 60.
#
#     2. we can observe DailyRate & EmployeeNumber,MonthlyRate columns the standard deviation is higher, and we can see higher          difference
#        75% and max value so we can conclude that there must be outliers present.
#
#     3. we can also observe higher standard deviation HourlyRate.

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# lets plot with Target variable and check the value counts.
import matplotlib.pyplot as plt
print(data['Attrition'].value_counts())
sns.countplot(x='Attrition', data=data, palette='rainbow')
plt.show()
#observation: we can observe that the number of value count for yes in attrition is less compare to no attrition, which means we can say there we get large skewed value.
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#lets plot the Buisness Travel with respect to age and Attrition
print(data['BusinessTravel'].value_counts())
sns.set(style='ticks')
sns.violinplot(x='BusinessTravel',y='Age',data=data,hue='Attrition',split=True)
plt.show()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [raw]
# # obervation:
#     1. we can obserserve people age from 45 to 60 with or without attrition Travel less.
#     2. we can observe the age 25 tgo 45 comes most under the category to travel_rarely.
#     3. People From the 25 to 35 Travel most_frquently.
#     4. Non Travel count is less,compare to others, we can say people from 30 to 45 have to travel less.

# %%
# lets check ratio of Daily rate based on Different Age
import numpy as np
plt.figure(figsize=(20,8))
sns.set_style('whitegrid')
plt.xticks(np.linspace(1,2,5))
plt.title('Daily rate based on Age',{'fontsize':20})
data.groupby("Age")["DailyRate"].sum().sort_values(ascending=False).plot(kind="bar",figsize=(15,5))
plt.xlabel('Age',{'fontsize' : 'large'})
plt.ylabel('DailyRate',{'fontsize':'large'})
# Out:
# Text(0, 0.5, 'DailyRate')

# %% [raw]
# Observation:
#     -->>we can oberve above that people from age 29 to 40 are getting highest Daily rate irrespective of there education or             department.
#     -->> Age belongs to 35 Year getting highest Daily Rate.

# %%
#lets check the Daily Rate of employee based on department and Education Field.
plt.figure(figsize=(12,7))
print('Department')
print(data['Department'].value_counts())
print('-------------------------------------')
print('EducationField')
print(data['EducationField'].value_counts())
plt.title('Monthly Income based on Department and There Education fields',{'fontsize':20})
sns.barplot(x='Department',y='MonthlyIncome',data=data,hue='EducationField')
plt.show()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# -------------------------------------
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [raw]
# observation:
#     1. we can observe that in sales department people belongs to Marketting and Life Science making higher monthly income.
#     2. In the field of R&D People belongs to Medical making higher monthly income.
#     3. In the Human resource department people from Human resource department highest salary, we can observe above, lets check        with attrition below.

# %%
#lets check the Attrition of department based on TrainingTimesLastYear.
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(12,7))
plt.title('Attrition based on Department and TrainingTimesLastYear',{'fontsize':20})
sns.swarmplot(x='Department',y='TrainingTimesLastYear',data=data,hue='Attrition')
plt.show()

# %% [raw]
# observation:
#     As we can oberve based on Training time last year Sales department is having More Attrition while lowest we can observe in     the human resource department.

# %%
# lets check the attrition based on distance.
plt.figure(figsize=(15,8))
print(data['Attrition'].value_counts())
print('-------------------------------------')
plt.title(' Attriton in company based on Distance from Home to office',{'fontsize':20})
sns.lineplot(x='DistanceFromHome',y='Age',data=data,hue='Attrition',palette="Set1", marker='o')
sns.barplot(x='DistanceFromHome',y='Age',data=data)
plt.show()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# -------------------------------------

# %% [raw]
# observation:
#     1. As we can observe above that the distance can be criteria for attrition in company, as the distance increases more the          Attrition we can observe ireespective of the payment.

# %%
# let check the attrition Rate for Monthly salary based on age.
plt.figure(figsize=(15,8))
plt.title(' Attriton in company Based on Monthly Salary and Age',{'fontsize':20})
sns.barplot(x='Age',y='MonthlyIncome',data=data,hue='Attrition',palette="Set1")
# Out:
# <AxesSubplot:title={'center':' Attriton in company Based on Monthly Salary and Age'}, xlabel='Age', ylabel='MonthlyIncome'>

# %% [raw]
# obervation:
#     1. employee below age 35 the attrition rate is between 50-60%.
#     2. we can also observe as the age and experience increases the Attrition rate is also increasing proportionally.
#     3. After the age 55 the attrition rate is quite low cause the retirement time came and all.

# %%
# let check the attrition Rate expereince with their JOBROLE.
plt.figure(figsize=(15,8))
plt.title(' Attriton in company Based expereince with their JOBROLE',{'fontsize':20})
sns.lineplot(x='JobRole',y='TotalWorkingYears',hue='Attrition',data=data,palette="Set2", marker='o')
sns.barplot(x='JobRole',y='TotalWorkingYears',hue='Attrition',data=data,palette="rainbow")
plt.xlabel('Job role')
plt.ylabel('Total working Experience')
plt.xticks(rotation=30)
plt.show()

# %% [raw]
# observation:
#     1. we can observe above the Sales executive attrition rate is equal.
#     2. where as we can see that the Manager and Research Director as there working experience increases there attrition rate is        also increases.

# %%
#lets plot Attrition on diffrent data parameter.
fig, axes = plt.subplots(3, 2, figsize=(25, 18))

fig.suptitle('Attrition based on different parameters',fontsize=25)
sns.set_style('whitegrid')

sns.barplot(ax=axes[0, 0],x='Age',y='MaritalStatus',hue='Attrition',data=data,palette="Set1")
sns.lineplot(ax=axes[0, 1],x='YearsWithCurrManager',y='YearsSinceLastPromotion',hue='Attrition',marker='o',data=data,palette="Set2")
sns.barplot(ax=axes[1, 0],x='JobLevel',y='TotalWorkingYears',hue='Attrition',data=data,palette="rainbow")
sns.barplot(ax=axes[1, 1],x='WorkLifeBalance',y='Gender',hue='Attrition',data=data,palette="icefire_r")
sns.barplot(ax=axes[2, 0],x='EnvironmentSatisfaction',y='NumCompaniesWorked',hue='Attrition',data=data,palette="autumn")
sns.barplot(ax=axes[2, 1],x='TrainingTimesLastYear',y='MonthlyIncome',hue='Attrition',data=data,palette="rainbow_r")
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='MonthlyIncome'>

# %% [raw]
# observation:
#     1. we can observe above that for both married and divorced status employee based on their age the Attrition rate is high.
#     2. AS working with current Manager and the gap in since last promotion a the working year with manager is increasing we can        also
#        notice increase in Attrition rate.
#     3. We can notice as the working year and job level increases the Attrition rate Is also increases.
#     4. If we are observing worklife balance on bais of Gender FEmales are having more Attrition Rate.
#     5. Environment satisfaction is also playing a role For Attrition rate as we can observe if environment satisfaction are            poor & people who changes their job just for environmentsatisfaction, if Environment satisfaction are poor Attirition          rate goes high.
#     6. Based on training last year is the monthly income is less Attrition rate goes high.
#
#     so far i can observe that the overall all the parameters are the criteria for Attrition but the major i can see is the         monthly income,years of experience but getting less salary,employee below age 30 the attrition rate is almost fifty             percent, and as the work experience increases and salary become criteria for Attrition.

# %% [markdown]
# # Lets start building the model for prediction

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# we can observe that some solumn is having numeric value so lets convert that column to numeric.
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#let convert all the object file To int to make more input countable for building model.
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
mod=['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime','Over18']
for i in mod:
    data[i]=le.fit_transform(data[i])

# %%
# lets sepearate input output columns
df_x=data.drop(columns=['Attrition']) # Input variable.
y=pd.DataFrame(data['Attrition']) #Target Variable.

# %%
df_x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %% [markdown]
# # To check distribution of skewness

# %%
for i in df_x.columns:
    sns.distplot(df_x[i])
    plt.show()
# we can observe some of the column is almost normally distributed where as some were skewed. lets check skewness value.

# %%
#lets check the skewness of data.
df_x.skew()
# we can observe that some of data is been skewed
# Out:
# Age                         0.413286
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %%
# lets apply log transformation and treat the skewd data
for col in df_x.columns:
    if df_x.skew().loc[col]>0.55:
        df_x[col]=np.log1p(df_x[col])

# %%
df_x.skew()
# we can observe that the data is much more countable than before.
# Out:
# Age                         0.413286
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.029121
# Education                  -0.289681
# EducationField             -0.054786
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.286448
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.513543
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %% [raw]
# #lets remove the outliers using zscore
# from scipy.stats import zscore
# z=abs(zscore(data))
# print(data.shape)
# new=data.loc[(z<3).all(axis=1)]
# print(new.shape)
#  #if we are trying to remove the outliers all the data is been erased so lets just skip the removing of outliers and go ahead with classification regression.

# %% [raw]
# Now EDA process is been completed.

# %% [markdown]
# # Model Training
# As we can observe in this data set , that we can predict this Attrition
# so we can use here logistic regression cause my Target variable is in binary value 0 or 1.

# %%
# as we can see the column is big so we can reduce it to 10 with PCA
from sklearn.decomposition import PCA
pca=PCA(n_components=10)
xpca=pca.fit_transform(df_x)
df_x=pd.DataFrame(xpca)
df_x
# Out:
#                  0            1           2          3          4         5  \
# 0      5164.231925 -1046.373144 -245.455552 -29.262212   3.139616 -2.787006
# 1     10593.728992 -1001.516854  566.422036   2.358518  11.597051 -1.741455
# 2    -11919.222385 -1039.666030 -486.040851 -26.154930  -0.228067  2.371258
# 3      8843.698449 -1064.534609 -541.585163   9.058750  -4.460426 -1.292622
# 4      2318.182051 -1005.803459  269.308027  24.390808  -9.702095  2.970596
# ...            ...          ...         ...        ...        ...       ...
# 1465  -2022.130098  1031.580662 -141.149667  26.366303  -0.280784  2.496776
# 1466   7145.346419  1038.268845  113.134212  24.593133   2.527185  4.449699
# 1467  -9136.778693  1087.677833  598.774092 -20.118339  -9.529131  0.758398
# 1468  -1069.382870  1025.961272 -281.843816   4.339536  12.196496 -3.066273
# 1469  -4083.651157  1056.725344  117.520187 -14.831021  -2.727873  2.443358
#
#              6         7         8         9
# ...

# %%
#Before moving forward lets scale our data.
# lets scale the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)
x
# WE CAN NOTICE OUR DATA IS BEEN SCALED.
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.725784 -1.737018 -0.610240 -1.441264  0.342735 -1.129382  0.077552
# 1     1.488849 -1.662554  1.408211  0.116165  1.265988 -0.705692 -0.265573
# 2    -1.675135 -1.725883 -1.208371 -1.288220 -0.024897  0.960908  2.083906
# 3     1.242899 -1.767166 -1.346463  0.446174 -0.486921 -0.523811 -0.178859
# 4     0.325799 -1.669670  0.669540  1.201331 -1.059126  1.203779  0.324467
# ...        ...       ...       ...       ...       ...       ...       ...
# 1465 -0.284191  1.712461 -0.350919  1.298630 -0.030652  1.011772  0.403808
# 1466  1.004211  1.723564  0.281269  1.211296  0.275879  1.803157 -0.514437
# 1467 -1.284089  1.805585  1.488643 -0.990897 -1.040244  0.307327 -0.108903
# 1468 -0.150292  1.703133 -0.700706  0.213737  1.331426 -1.242550 -0.061986
# 1469 -0.573919  1.754203  0.292173 -0.730478 -0.297787  0.990125  0.124386
#
#              7         8         9
# ...

# %%
#lets check the skewness again
x.skew()
# Out:
# 0    0.018582
# 1    0.013170
# 2    0.006846
# 3    0.031781
# 4    0.394077
# 5    0.353374
# 6    0.190951
# 7    0.140865
# 8    0.206485
# 9    0.215608
# dtype: float64

# %%
# Breaking our input and target data into train and test data.
from sklearn.model_selection import train_test_split,cross_val_score
import warnings
warnings.filterwarnings('ignore')
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state=48,stratify=y)

# %%
#importing varios classification model
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
#importing error matrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# saving different algorithm with respective name
KNN=KNeighborsClassifier()
SVC=SVC()
LR=LogisticRegression()
DT=DecisionTreeClassifier()
GNB=GaussianNB()

# %%
models= []
models.append(('KNeighborsClassifier',KNN))
models.append(('SVC',SVC))
models.append(('LogisticRegression',LR))
models.append(('DecisionTreeClassifier',DT))
models.append(('GaussianNB',GNB))

# %%
from sklearn.metrics import accuracy_score,roc_curve,auc,confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score,cross_val_predict
import seaborn as sns

# %%
# lets make the for loop and call the algorithm one by one and save data to respective model using append function.
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print('******************************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('cross_val_score',sc)
    cvs.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score = ',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,50))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate, label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.show()
    
    print('\n\n\n')
# Out:
# ****************************** KNeighborsClassifier ***************************
#
#
# KNeighborsClassifier(n_neighbors=9)
#
#
# accuracy_score= 0.8571428571428571
#
#
# cross_val_score 0.8387755102040817
#
#
# roc_auc_score =  0.5531914893617021
#
#
# classification_report               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       247
#            1       1.00      0.11      0.19        47
#
#     accuracy                           0.86       294
#    macro avg       0.93      0.55      0.56       294
# weighted avg       0.88      0.86      0.81       294
#
#
#
# [[247   0]
#  [ 42   5]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ****************************** SVC ***************************
#
#
# SVC()
#
#
# accuracy_score= 0.8435374149659864
#
#
# cross_val_score 0.8401360544217689
#
#
# roc_auc_score =  0.5106382978723404
#
#
# classification_report               precision    recall  f1-score   support
#
# ...

# %%
# saving the result to a single datframe.
result=pd.DataFrame({'Model':Model, 'Accuracy_score': score,'Cross_val_score':cvs,'roc_auc_score':rocscore})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score  roc_auc_score
# 0    KNeighborsClassifier       85.714286        83.877551      55.319149
# 1                     SVC       84.353741        84.013605      51.063830
# 2      LogisticRegression       83.333333        84.353741      50.456542
# 3  DecisionTreeClassifier       74.149660        71.360544      57.911965
# 4              GaussianNB       84.693878        84.421769      52.989060

# %% [raw]
# Observation:
#     we can observe above that Kneighbors is working well with good accuracy acore, followed by SVC and and Gaussian NB.

# %%
# lets apply grid search cv to get the best parameters
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsClassifier()
gknr=GridSearchCV(knr,neighbors,cv=5)
gknr.fit(x_train,y_train)
print(gknr.best_params_)
print(gknr.best_score_)
# Out:
# {'n_neighbors': 7}
# 0.842683014785431

# %%
knr=KNeighborsClassifier(n_neighbors=9)
knr.fit(x_train,y_train)
pred=knr.predict(x_test)
print("Accuracy for Kneighbors classifier : ",accuracy_score(y_test,pred)*100)
print('Cross validation score with Kneighbors :',cross_val_score(knr,x,y,cv=10,scoring='accuracy').mean()*100)
# so we can observe below a better result of kneighbors using grid search cv, lets explore more.
# Out:
# Accuracy for Kneighbors classifier :  85.71428571428571
# Cross validation score with Kneighbors : 83.87755102040816

# %% [raw]
# obsrvation:
#
#     After applying Grid search Cv We got the best accuracy of Kneighbors which is almost 86% which quite good for model,with       cvscore of 83.87%.

# %% [markdown]
# # Using Ensemble boosting Technique.

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(random_state=48)
parameters={'n_estimators':[10,100,500,1000],'criterion' :['gini', 'entropy']}
rfc=GridSearchCV(estimator=rfc,param_grid=parameters,cv=5)
rfc.fit(x_train,y_train)
print(rfc.best_params_)
print(rfc.best_score_)
# Out:
# {'criterion': 'gini', 'n_estimators': 500}
# 0.8486404615939416

# %%
rfc1=RandomForestClassifier(random_state=48,n_estimators=500,criterion='gini')
rfc1.fit(x_train,y_train)
pred=rfc1.predict(x_test)
print("Accuracy for Random Forest classifier: ",accuracy_score(y_test,pred)*100)
print('Cross validation score with Kneighbors :',cross_val_score(rfc1,x,y,cv=5,scoring='accuracy').mean()*100)
# Out:
# Accuracy for Random Forest classifier:  84.6938775510204
# Cross validation score with Kneighbors : 84.6938775510204

# %%
from sklearn.ensemble import AdaBoostClassifier
adc=AdaBoostClassifier()
knr=KNeighborsClassifier()
parameters={'n_estimators':[500,1000,2000],'learning_rate':[.001,0.01,.1]}
adc=GridSearchCV(estimator=adc,param_grid=parameters,cv=5)
adc.fit(x_train,y_train)
print(adc.best_params_)
print(adc.best_score_)
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}
# 0.8435340786152181

# %%
adc=AdaBoostClassifier(n_estimators=1000,learning_rate=0.0001)
adc.fit(x_train,y_train)
pred=adc.predict(x_test)
print("Accuracy for ADA on CV data: ",accuracy_score(y_test,pred))
print('Cross validation score with Kneighbors :',cross_val_score(adc,x,y,cv=5,scoring='accuracy').mean()*100)
# Out:
# Accuracy for ADA on CV data:  0.8401360544217688
# Cross validation score with Kneighbors : 83.87755102040816

# %% [raw]
# obseration:
#     #lets test the predicted output of two model which is Kneighbors and Random Forest Classifier ,before finalising the model.

# %%
#Predicting result for Random Forest Classifier.
Hr_prediction_rfc1=rfc1.predict(x)
print('Prediction For random forest Classifier',Hr_prediction_rfc1)
print(sns.distplot([Hr_prediction_rfc1]))
plt.show()
# Out:
# Prediction For random forest Classifier [1 0 1 ... 0 0 0]
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Predicting result for Kneighbors Classifier.
knr=KNeighborsClassifier(n_neighbors=9)
knr.fit(x_train,y_train)
pred=knr.predict(x_test)
print("Accuracy for Kneighbors classifier : ",accuracy_score(y_test,pred)*100)
print('Cross validation score with Kneighbors :',cross_val_score(knr,x,y,cv=10,scoring='accuracy').mean()*100)
# so we can observe below a better result of kneighbors using grid search cv, lets explore more.
# Out:
# Accuracy for Kneighbors classifier :  85.71428571428571
# Cross validation score with Kneighbors : 83.87755102040816

# %%
Hr_prediction=knr.predict(x)
print('Prediction For random forest Classifier',Hr_prediction)
print(sns.distplot([Hr_prediction]))
plt.show()
# Out:
# Prediction For random forest Classifier [0 0 0 ... 0 0 0]
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [raw]
# observation:
#     -->>After Observing Above graph we can say that the random forest is Working well on the basis of graph, as the attrtion of         yes count is less so on the basis of that the random forest is giving me the best result according to my dataset                execution.
#     --->>so we can observe the result for Random Forest classifier are as below.
#
#             *Accuracy for Random Forest classifier:  84.69401360544217
#             *Cross validation score with Kneighbors : 84.6938775510204
#
#  So lets finalise the Random forest model for prediction.

# %%
# finalising the Random Forest Model.
rfc1=RandomForestClassifier(random_state=48,n_estimators=500,criterion='gini')
rfc1.fit(x_train,y_train)
pred=rfc1.predict(x_test)
print("Accuracy for Random Forest classifier: ",accuracy_score(y_test,pred)*100)
print('Cross validation score with Kneighbors :',cross_val_score(rfc1,x,y,cv=5,scoring='accuracy').mean()*100)
# Out:
# Accuracy for Random Forest classifier:  84.6938775510204
# Cross validation score with Kneighbors : 84.6938775510204

# %%
# lets Save the model
import joblib
joblib.dump(rfc1,'HR analytics.pkl')
# Out:
# ['HR analytics.pkl']

# %% [markdown]
# # Lets save the predicted output to csv file.

# %%
#lets save the predicted result to excel file.
df=pd.DataFrame(Hr_prediction_rfc1)
df.to_csv('Hr_Classification_prediction_result.csv')

# %% [markdown]
# # Conclusion:

# %% [raw]
# 1. After getting insight of HR analytics dataset we came to various conclusion that how much the Attrition can imapact on          Company.
#
# 2. In my first attempt to address the attrition issue in the company as per the data provided is been analyzed and various plot    has been plotted on the basis of Attrition.
#
# 3. Our main challenge was to predict the Attrition rate of company though attrition with value Yes having less number compare      to no the Value was predicted using various Machine learning model.
#
# 4. Even we predicted the value with various ensemble boosting technique, analyzed every model with its best parameters using      grid search cv.
#
# 5. We came to conclusion that Kneighbors and random Forest classifier was working quite well thus we predicted input with both    the model and plotted dist plot, and we came to see that Random forest was working quite well.
#
# 6. We save our best model with Random Forest Classifier with Accuracy score of 85%,and Cross validation score of 83%, and I        plotted the predicted result as the value of attrion rate with yes was low thus as per the input, output has been reflected.
#
# 7. I can say there ay lots of possible chances of improoving the model futher,using various algorihm and plotting technique.
